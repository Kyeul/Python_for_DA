# %% [markdown]
# ## 하나의 웹 사이트에 접속하기
# ### webbrowser 모듈

# %%
import webbrowser as wb

url = 'www.naver.com'

# %%
wb.open(url)
# Out:
# True

# %% [markdown]
# ##### 네이버에 검색어로 웹 브라우저 열기

# %%
naver_search_url="https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query="
search_word ='파이썬'
url = naver_search_url + search_word

wb.open(url)
# Out:
# True

# %% [markdown]
# ### request 모듈 & BeautifulSoup 모듈

# %%
import requests
from bs4 import BeautifulSoup

# %%
html = requests.get("https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=047&aid=0002228430").text
html
# Out:
# '<!DOCTYPE HTML> \r\n<html lang="ko"> \r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta name="viewport" content="width=1106" />\r\n<title>현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구 : 네이버 뉴스</title>\r\n\n\n\t\n\t\n\t\t\n\t\n\n\n\t\n\t\n\t\n\t\t\n\t\t\n\t\t\n\t\n\n<meta property="me2:post_tag"\t\tcontent="오마이뉴스 : 네이버뉴스"/>\n<meta property="me2:category1"\t\tcontent="오마이뉴스"/>\n<meta property="me2:category2"\t\tcontent="정치"/>\n<meta property="me2:image"\t\t\tcontent="https://imgnews.pstatic.net/image/047/2019/05/28/0002228430_001_20190528093504844.jpg"/>\n\n<meta property="og:title"\t\t\tcontent="현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구"/>\n<meta property="og:type"\t\t\tcontent="article"/>\n<meta property="og:url"\t\t\t\tcontent="http://news.naver.com/main/read.nhn?mode=LSD&mid=sec&oid=047&aid=0002228430&sid1=001"/>\n<meta property="og:image"\t\t\tcontent="https://imgnews.pstatic.net/image/047/2019/05/28/0002228
# ...

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="width=1106" name="viewport"/>
# <title>현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구 : 네이버 뉴스</title>
# <meta content="오마이뉴스 : 네이버뉴스" property="me2:post_tag"/>
# <meta content="오마이뉴스" property="me2:category1"/>
# <meta content="정치" property="me2:category2"/>
# <meta content="https://imgnews.pstatic.net/image/047/2019/05/28/0002228430_001_20190528093504844.jpg" property="me2:image"/>
# <meta content="현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;oid=047&amp;aid=0002228430&amp;sid1=001" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/047/2019/05/28/0002228430_001_20190528093504844.jpg" property="og:image"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta contents="always" name="referrer"/>
#   <meta content="width=1106" name="viewport"/>
#   <title>
#    현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구 : 네이버 뉴스
#   </title>
#   <meta content="오마이뉴스 : 네이버뉴스" property="me2:post_tag"/>
#   <meta content="오마이뉴스" property="me2:category1"/>
#   <meta content="정치" property="me2:category2"/>
#   <meta content="https://imgnews.pstatic.net/image/047/2019/05/28/0002228430_001_20190528093504844.jpg" property="me2:image"/>
#   <meta content="현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;oid=047&amp;aid=0002228430&amp;sid1=001" property="og:url"/>
#   <meta content="https://imgnews.pstatic.net/image/047/2019/05/28/0002228430_001_20190528093504844.jpg" property="og:image"/>
# ...

# %%
soup.title
# Out:
# <title>현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구 : 네이버 뉴스</title>

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div id="wrap">
#   <div id="da_base">
#   </div>
#   <div id="da_stake">
#   </div>
#   <div class="header" id="header">
#    <div id="u_skip">
#     <a href="#lnb" tabindex="1">
#      <span>
#       메인 메뉴로 바로가기
#      </span>
#     </a>
#     <a href="#main_content" tabindex="2">
#      <span>
#       본문으로 바로가기
#      </span>
#     </a>
#    </div>
#    <div class="snb_area">
#     <div class="snb_inner">
#      <div class="gnb_wrap">
#       <!-- GNB 마크업 -->
#       <div id="gnb">
#       </div>
#       <!-- //GNB 마크업 -->
#      </div>
#      <div id="snb_wrap">
#       <h1>
#        <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/">
#         <span class="blind">
#          NAVER
#         </span>
#        </a>
#        <a class="h_news nclicks(STA.news)" href="/">
#         <span class="blind">
#          뉴스
#         </span>
#        </a>
#       </h1>
#       <ul class="snb_related_service">
#        <li>
#         <span class="snb_bdr">
# ...

# %%
soup.select('#articleBodyContents')
# Out:
# [<div id="articleBodyContents">
#  <!-- 본문 내용 -->
#  <!-- TV플레이어 -->
#  <!-- // TV플레이어 -->
#  <script type="text/javascript">
#  // flash 오류를 우회하기 위한 함수 추가
#  function _flash_removeCallback() {}
#  </script>
# ...

# %%
title = soup.title
contents = soup.find_all('div', {"id": "articleBodyContents"})

print(title.get_text())
for content in contents:
    print(content.get_text())
# Out:
# 현대중공업노조, 주총장 기습 점거... 긴박한 울산 동구 : 네이버 뉴스
#
#
#
#
#
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
#
# ...

# %%
con=contents[0].get_text()

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

token=kkma.nouns(con)

# %%
for i in range(2):
    token1.pop()

# %%
token1 = kkma.nouns(title.get_text())

# %%
for i in range(3):
    token += token1

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(
    font_path='C:/Windows/Fonts/malgun.ttf',
    background_color='white'
).generate(' '.join(token))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
list1 = [1,2,3]
list2 = [4,5,6]

# %%
list3 = list1 + list2

# %%
list3
# Out:
# [1, 2, 3, 4, 5, 6]
